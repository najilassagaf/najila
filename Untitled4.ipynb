# %%
import pandas as pd

# %%
dataset = '/content/encoded_cleaned_test.csv'

# %%
data = pd.read_csv(dataset)

# %%
data
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  \
# 0      0x2318    COIMBRES13DEL01                  NaN
# 1      0x3474     BANGRES15DEL01                 28.0
# 2      0x9420      JAPRES09DEL03                 23.0
# 3      0x72ee      JAPRES07DEL03                 21.0
# 4      0xa759     CHENRES19DEL01                 31.0
# ...       ...                ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0
# 11395  0x443b      JAPRES11DEL01                 33.0
# 11396  0x1ea5      SURRES11DEL03                  NaN
# 11397  0x22d4      VADRES03DEL02                 27.0
# 11398  0xb7be     CHENRES07DEL02                 39.0
#
#        Delivery_person_Ratings  Restaurant_latitude  Restaurant_longitude  \
# 0                          NaN            11.003669             76.976494
# 1                          4.6            12.975377             77.696664
# 2                          4.5            26.911378             75.789034
# ...

# %%
data.head(7)
# Out:
#        ID Delivery_person_ID  Delivery_person_Age  Delivery_person_Ratings  \
# 0  0x2318    COIMBRES13DEL01                  NaN                      NaN
# 1  0x3474     BANGRES15DEL01                 28.0                      4.6
# 2  0x9420      JAPRES09DEL03                 23.0                      4.5
# 3  0x72ee      JAPRES07DEL03                 21.0                      4.8
# 4  0xa759     CHENRES19DEL01                 31.0                      4.6
# 5  0xc4af      GOARES04DEL01                 26.0                      4.7
# 6  0x3b9d     BANGRES19DEL02                 23.0                      4.8
#
#    Restaurant_latitude  Restaurant_longitude  Delivery_location_latitude  \
# 0            11.003669             76.976494                   11.043669
# 1            12.975377             77.696664                   13.085377
# 2            26.911378             75.789034                   27.001378
# 3            26.766536             75.837333                   26.856536
# ...

# %%
print(data.dtypes)
# Out:
# ID                              object
# Delivery_person_ID              object
# Delivery_person_Age            float64
# Delivery_person_Ratings        float64
# Restaurant_latitude            float64
# Restaurant_longitude           float64
# Delivery_location_latitude     float64
# Delivery_location_longitude    float64
# Order_Date                      object
# Time_Orderd                     object
# Time_Order_picked               object
# Weather                          int64
# Road_traffic_density             int64
# Vehicle_condition                int64
# Type_of_order                    int64
# Type_of_vehicle                 object
# multiple_deliveries            float64
# Festival                       float64
# City                            object
# Name:                           object
# dtype: object

# %%
datanoid = data.drop(data.columns[3],axis=1)

# %%
datanoid
# Out:
#            ID Delivery_person_ID  Delivery_person_Age  Restaurant_latitude  \
# 0      0x2318    COIMBRES13DEL01                  NaN            11.003669
# 1      0x3474     BANGRES15DEL01                 28.0            12.975377
# 2      0x9420      JAPRES09DEL03                 23.0            26.911378
# 3      0x72ee      JAPRES07DEL03                 21.0            26.766536
# 4      0xa759     CHENRES19DEL01                 31.0            12.986047
# ...       ...                ...                  ...                  ...
# 11394  0x6909      JAPRES01DEL01                 35.0            26.905190
# 11395  0x443b      JAPRES11DEL01                 33.0            26.902940
# 11396  0x1ea5      SURRES11DEL03                  NaN            21.157735
# 11397  0x22d4      VADRES03DEL02                 27.0            22.320000
# 11398  0xb7be     CHENRES07DEL02                 39.0            13.081878
#
#        Restaurant_longitude  Delivery_location_latitude  \
# ...

# %%
data.describe()
# Out:
#        Delivery_person_Age  Delivery_person_Ratings  Restaurant_latitude  \
# count         10908.000000             10892.000000         11399.000000
# mean             29.517235                 4.632786            17.099934
# std               5.797077                 0.344081             8.193510
# min              15.000000                 1.000000           -30.902872
# 25%              25.000000                 4.500000            12.933284
# 50%              30.000000                 4.700000            18.551440
# 75%              34.000000                 4.900000            22.732225
# max              50.000000                 6.000000            30.914057
#
#        Restaurant_longitude  Delivery_location_latitude  \
# count          11399.000000                11399.000000
# mean              70.399259                   17.569497
# std               22.773144                    7.287440
# min              -88.400467                    0.010000
# ...

# %%
data.loc[:,"Delivery_person_Age":].corr()
# Out:
# <ipython-input-12-c071fabf8408>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.loc[:,"Delivery_person_Age":].corr()
#                              Delivery_person_Age  Delivery_person_Ratings  \
# Delivery_person_Age                     1.000000                -0.056203
# Delivery_person_Ratings                -0.056203                 1.000000
# Restaurant_latitude                     0.001284                 0.011304
# Restaurant_longitude                    0.000381                 0.017036
# Delivery_location_latitude              0.005439                 0.000604
# Delivery_location_longitude            -0.002318                -0.001883
# Weather                                 0.016311                -0.049078
# Road_traffic_density                    0.004745                 0.042385
# ...

# %%
# @title restaurant latitude vs restaurant longitude

from matplotlib import pyplot as plt
data.plot(kind='scatter', x='Restaurant_latitude', y='Restaurant_longitude', s=42, alpha=.9)
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
# !pip install kaggle

# %%
import os
from google.colab import files

if not os.path.exists("/root/.kaggle/kaggle.json"):
    uploaded = files.upload()
    for fn in uploaded.keys():
        print('User uploaded file "{name}" with length {length} bytes'.format(
            name=fn, length=len(uploaded[fn])))
    # Pindahkan file kaggle.json ke direktori yang tepat
    # !mkdir -p ~/.kaggle
    # !mv kaggle.json ~/.kaggle/
    # !chmod 600 /root/.kaggle/kaggle.json
# Out:
#      <input type="file" id="files-2c384eaf-13a9-4fd4-8c30-671bc1cb0777" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2c384eaf-13a9-4fd4-8c30-671bc1cb0777">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !kaggle datasets list -s "amazon"
# Out:
# ...
# ref                                                    title                                         size  lastUpdated          downloadCount  voteCount  usabilityRating
# -----------------------------------------------------  -------------------------------------------  -----  -------------------  -------------  ---------  ---------------
# karkavelrajaj/amazon-sales-dataset                     Amazon Sales Dataset                           2MB  2023-01-17 06:21:15          69488        509  1.0
# kritanjalijain/amazon-reviews                          Amazon reviews                                 1GB  2021-05-15 09:45:40          12050        135  1.0
# snap/amazon-fine-food-reviews                          Amazon Fine Food Reviews                     242MB  2017-05-01 18:51:31         175238       2177  0.7941176
# abdallahwagih/amazon-reviews                           Amazon reviews                                44MB  2023-10-16 18:25:58           1659         62  1.0
# ...

# %%
# !kaggle datasets download karkavelrajaj/amazon-sales-dataset
# Out:
# ...
#   0% 0.00/1.95M [00:00<?, ?B/s]
# 100% 1.95M/1.95M [00:00<00:00, 148MB/s]

# %%
# !unzip /content/amazon-sales-dataset.zip
# Out:
# Archive:  /content/amazon-sales-dataset.zip
#   inflating: amazon.csv

# %%
pd.read_csv('/content/amazon.csv')
# Out:
#       product_id                                       product_name  \
# 0     B07JW9H4J1  Wayona Nylon Braided USB to Lightning Fast Cha...
# 1     B098NS6PVG  Ambrane Unbreakable 60W / 3A Fast Charging 1.5...
# 2     B096MSW6CT  Sounce Fast Phone Charging Cable & Data Sync U...
# 3     B08HDJ86NZ  boAt Deuce USB 300 2 in 1 Type-C & Micro USB S...
# 4     B08CF3B7N1  Portronics Konnect L 1.2M Fast Charging 3A 8 P...
# ...          ...                                                ...
# 1460  B08L7J3T31  Noir Aqua - 5pcs PP Spun Filter + 1 Spanner | ...
# 1461  B01M6453MB  Prestige Delight PRWO Electric Rice Cooker (1 ...
# 1462  B009P2LIL4  Bajaj Majesty RX10 2000 Watts Heat Convector R...
# 1463  B00J5DYCCA  Havells Ventil Air DSP 230mm Exhaust Fan (Pist...
# 1464  B01486F4G6  Borosil Jumbo 1000-Watt Grill Sandwich Maker (...
#
#                                                category discounted_price  \
# 0     Computers&Accessories|Accessories&Peripherals|...             ₹399
# ...
